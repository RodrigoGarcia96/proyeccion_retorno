# %% [markdown]
# ## Planteamineto
#
# Se menciona que se tienen $500,000 para invertir. ¿Que negocio o plan de inverión es mejor?
# ¿En donde es más redituable aplicarlo teniendo en cuenta solo 3 estado (CDMX,Hidalgo y Estado de México)?
